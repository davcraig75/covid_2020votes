# %%
import pandas as pd
df=pd.read_csv('merged.tsv', sep='\t',index_col=0)

# %%
df.head()
# Out:
#                   uid     year state state_po  county_name   county_fips  \
# autauga:alabama  2000  ALABAMA    AL  AUTAUGA       1001.0  US PRESIDENT
# autauga:alabama  2000  ALABAMA    AL  AUTAUGA       1001.0  US PRESIDENT
# autauga:alabama  2000  ALABAMA    AL  AUTAUGA       1001.0  US PRESIDENT
# autauga:alabama  2000  ALABAMA    AL  AUTAUGA       1001.0  US PRESIDENT
# baldwin:alabama  2000  ALABAMA    AL  BALDWIN       1003.0  US PRESIDENT
#
#                          office   candidate  party  candidatevotes  \
# autauga:alabama         AL GORE    DEMOCRAT   4942           17208
# autauga:alabama  GEORGE W. BUSH  REPUBLICAN  11993           17208
# autauga:alabama     RALPH NADER       GREEN    160           17208
# autauga:alabama           OTHER       OTHER    113           17208
# baldwin:alabama         AL GORE    DEMOCRAT  13997           56480
#
#                  totalvotes version  modeDeathRate
# autauga:alabama    20220315   TOTAL       0.013617
# ...
